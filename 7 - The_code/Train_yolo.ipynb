# %%
# %pip uninstall -y torch torchvision torchaudio
# Out:
# Found existing installation: torch 2.5.1+cu121
# Uninstalling torch-2.5.1+cu121:
#   Successfully uninstalled torch-2.5.1+cu121
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Exception:
# Traceback (most recent call last):
#   File "c:\Users\Carol\Mestrado\Semestre 2\DeepLearning\2025 project\deep_learning_car_damage\Car-Damage-Image-segmentation\Car-damage-image-seg\venv\lib\site-packages\pip\_internal\cli\base_command.py", line 167, in exc_logging_wrapper
#     status = run_func(*args)
#   File "c:\Users\Carol\Mestrado\Semestre 2\DeepLearning\2025 project\deep_learning_car_damage\Car-Damage-Image-segmentation\Car-damage-image-seg\venv\lib\site-packages\pip\_internal\commands\uninstall.py", line 102, in run
#     uninstall_pathset.commit()
# ...

# %%
pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu126
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu126
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 25.1.1 is available.
# You should consider upgrading via the 'c:\Users\Carol\Mestrado\Semestre 2\DeepLearning\2025 project\deep_learning_car_damage\Car-Damage-Image-segmentation\Car-damage-image-seg\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# %%
# !nvidia-smi
# Out:
# Tue May 27 09:52:05 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 561.19                 Driver Version: 561.19         CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   50C    P5             17W /  140W |     739MiB /   6144MiB |      8%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import torch

# %%
from ultralytics import YOLO

# %%
import torch
print("PyTorch:", torch.__version__)
print("Built with CUDA:", torch.version.cuda)   # None ou 'cpu' = CPU-only
print("cuda.is_available():", torch.cuda.is_available())
# Out:
# PyTorch: 2.5.1+cu121
# Built with CUDA: 12.1
# cuda.is_available(): True

# %%
print("PyTorch:", torch.__version__)
print("Built with CUDA:", torch.version.cuda)  
print("cuda.is_available():", torch.cuda.is_available())
print("GPU count:", torch.cuda.device_count())
# Out:
# PyTorch: 2.7.0+cu126
# Built with CUDA: 12.6
# cuda.is_available(): True
# GPU count: 1

# %%
pip install ultralytics

# %% [markdown]
# * google drive: https://drive.google.com/drive/u/4/folders/1HYiSutyfD8aa9eNNeyoMbhAnJTUrV5NI

# %% [markdown]
# data augmentation:
#
# https://medium.com/@abhishekjainindore24/data-augmentation-in-object-detection-5c8ac110a9ba
#
# * pythorch seg model: https://medium.com/@heyamit10/pytorch-segmentation-models-a-practical-guide-5bf973a32e30
#
# transfer learning :
# https://medium.com/@paravisionlab/supercharge-your-ai-resnet50-transfer-learning-unleashed-b7c0e40976c4
#
# * other project para literature review: https://www.irjet.net/archives/V10/i1/IRJET-V10I180.pdf
#
# https://openaccess.thecvf.com/content/ICCV2021/papers/Azizi_Big_Self-Supervised_Models_Advance_Medical_Image_Classification_ICCV_2021_paper.pdf
#
#
#
# * yolov8 : https://roboflow.com/model/yolov8 , ou  https://docs.ultralytics.com/pt/models/yolov8/
#
# * v8 segmentation: https://docs.ultralytics.com/pt/tasks/segment/
#
# * yolov11: https://docs.ultralytics.com/pt/models/yolo11/

# %% [markdown]
# ### test models:

# %% [markdown]
# other seg car parts: https://docs.ultralytics.com/pt/datasets/segment/carparts-seg/#dataset-yaml

# %% [markdown]
# from feedback:
#
# **For YOLOv8: **
# yolo detect train data=data.yaml model=yolov8n.pt
# imgsz=640 epochs=50 lr0=0.01 frozen=10.

# %% [markdown]
# a pre-trained YOLO model (you can choose n, s, m, l, or x versions) https://docs.ultralytics.com/models/yolov8

# %% [markdown]
# avaliar o modelo:
# https://www.ultralytics.com/glossary/mean-average-precision-map
#
# https://www.geeksforgeeks.org/machine-learning-model-evaluation/
#
# roboflow: https://blog.roboflow.com/mean-average-precision/#:~:text=Average%20Precision%20(mAP)%3F-,Mean%20Average%20Precision%20(mAP),-is%20used%20to

# %% [markdown]
# fine tune : https://yolov8.org/how-to-use-fine-tune-yolov8/

# %% [markdown]
# poster:
# https://www.dropbox.com/scl/fi/zsuc0icyxmlw6my3tgmku/DL-Poster-Template-v2-2425.pptx?rlkey=avpbqvjzhiuw5yi9q8w0rnf5f&e=3&st=rpp1zlr6&dl=0 template
#
#
# https://pt.slideshare.net/slideshow/iaim-2023-poster-labelefficient-generalizable-deep-learning-for-medical-image-segmentation/259685542

# %%
import os
from ultralytics import YOLO
import cv2

# %%
import os
import cv2
import albumentations as A
import os
import cv2
import torch
from torch.utils.data import Dataset
import albumentations as A
from albumentations.pytorch import ToTensorV2
from albumentations.augmentations.geometric.transforms import Affine
# Out:
# c:\Users\Carol\Mestrado\Semestre 2\DeepLearning\2025 project\deep_learning_car_damage\Car-Damage-Image-segmentation\Car-damage-image-seg\venv\lib\site-packages\albumentations\__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.8' (you have '2.0.7'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %% [markdown]
# * change optimizer :
# https://docs.ultralytics.com/pt/modes/train/#train-settings
#
# can choose between SGD, Adam, AdamW, RAdam for the optimizer argument.
#
# ``` optimizer='Adam' ```
#
#
# contas e teoria por tras: https://www.lightly.ai/blog/which-optimizer-should-i-use-for-my-machine-learning-project

# %% [markdown]
# ---
# #### * YOLOv8m

# %%
model_v8m = YOLO('yolov8m-seg.pt')
#model_v8m = model_v8m.to('cuda')

# %%
model_v8m.info()
# Out:
# YOLOv8m-seg summary: 191 layers, 27,285,968 parameters, 0 gradients, 110.6 GFLOPs
# (191, 27285968, 0, 110.64632320000001)

# %% [markdown]
# ##### v8m - 10

# %%
#treinar o modelo:
#10 epochs:
model_v8m = YOLO('yolov8m-seg.pt')
model_v8m.train(data='./config.yaml', imgsz=640, epochs=10, lr0=0.01, freeze=10, project='runs/segment', name='v8m_10')
metrics = model_v8m.val()
print(metrics)
#ate podemos testar 1 sem freeze para ver se a velocidade muda muito
#model_v8m.train(data='./config.yaml', imgsz=640, epochs=15, lr0=0.01)
# Out:
# Ultralytics 8.3.145  Python-3.9.13 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
#treinar o modelo v8m 10 epochs mas com bacth size diferente:
#10 epochs:
model_v8m = YOLO('yolov8m-seg.pt')
model_v8m.train(data='./config.yaml', batch=20, imgsz=640, epochs=10, lr0=0.01, freeze=10, project='runs/segment', name='v8m_10_bs64')

#ate podemos testar 1 sem freeze para ver se a velocidade muda muito
#model_v8m.train(data='./config.yaml', imgsz=640, epochs=15, lr0=0.01)
# Out:
# Ultralytics 8.3.145  Python-3.9.13 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
#10 epochs:
model_v8m = YOLO('yolov8m-seg.pt')
model_v8m.train(data='./config.yaml', optimizer='Adam', imgsz=640, epochs=10, lr0=0.01, freeze=10, project='runs/segment', name='v8m_10_adam')
# Out:
# Ultralytics 8.3.145  Python-3.9.13 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
#10 epochs:
model_v8m = YOLO('yolov8m-seg.pt')
model_v8m.train(data='./config.yaml', optimizer='Adam', imgsz=640, epochs=10, lr0=0.05, freeze=10, project='runs/segment', name='v8m_10_adamlr5')
# Out:
# Ultralytics 8.3.145  Python-3.9.13 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
#10 epochs:
model_v8m = YOLO('yolov8m-seg.pt')
model_v8m.train(data='./config.yaml', optimizer='Adam', imgsz=640, epochs=10, lr0=0.005, freeze=10, project='runs/segment', name='v8m_10_adamlr005')
# Out:
# Ultralytics 8.3.145  Python-3.9.13 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
#10 epochs:
model_v8m = YOLO('yolov8m-seg.pt')
model_v8m.train(data='./config.yaml', imgsz=640, epochs=10, lr0=0.05, freeze=10, project='runs/segment', name='v8m_10_lr5')
# Out:
# Ultralytics 8.3.145  Python-3.9.13 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
#10 epochs:
model_v8m = YOLO('yolov8m-seg.pt')
model_v8m.train(data='./config.yaml', optimizer='SGD', imgsz=640, epochs=10, lr0=0.01, freeze=10, project='runs/segment', name='v8m_10_SGDlr1')
# Out:
# Ultralytics 8.3.145  Python-3.9.13 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
#10 epochs:
model_v8m = YOLO('yolov8m-seg.pt')
model_v8m.train(data='./config.yaml', optimizer='RAdam', imgsz=640, epochs=10, lr0=0.01, freeze=10, project='runs/segment', name='v8m_10_RAdamlr1')
# Out:
# Ultralytics 8.3.145  Python-3.9.13 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
metrics = model_v8m.val()
print(metrics)

# %% [markdown]
# ##### Albumentations:

# %%
pip install albumentations

# %%
pip install ultralytics

# %%
import os
import cv2
import albumentations as A
import os
import cv2
import torch
from torch.utils.data import Dataset
import albumentations as A
from albumentations.pytorch import ToTensorV2
from albumentations.augmentations.geometric.transforms import Affine

# %%
import os
import cv2
import torch
from torch.utils.data import Dataset
import albumentations as A
from albumentations.pytorch import ToTensorV2
from albumentations.augmentations.geometric.transforms import Affine

# %% [markdown]
# https://medium.com/@k.sunman91/data-augmentation-on-ultralytics-for-training-yolov5-yolov8-97a8dab31fef

# %%
from ultralytics.data.augment import Albumentations
from ultralytics.utils import LOGGER, colorstr

def __init__(self, p=1.0):
        """Initialize the transform object for YOLO bbox formatted params."""
        self.p = p
        self.transform = None
        prefix = colorstr("albumentations: ")
        try:
            import albumentations as A         

            # Insert required transformation here
            T =[
                A.RandomRain(p=0.1, slant_lower=-10, slant_upper=10, 
                              drop_length=20, drop_width=1, drop_color=(200, 200, 200), 
                              blur_value=5, brightness_coefficient=0.9, rain_type=None),
                A.Blur(p=0.1),
                A.Rotate(limit = 10, p=0.5),
                A.MedianBlur(p=0.1),
                A.ToGray(p=0.01),
                A.CLAHE(p=0.01),
                A.ImageCompression(quality_lower=75, p=0.0)
            ]
            self.transform = A.Compose(T, bbox_params=A.BboxParams(format="yolo", label_fields=["class_labels"]))

            LOGGER.info(prefix + ", ".join(f"{x}".replace("always_apply=False, ", "") for x in T if x.p))
        except ImportError:  # package not installed, skip
            pass
        except Exception as e:
            LOGGER.info(f"{prefix}{e}")

# %%
Albumentations.__init__ = __init__
model_v8m = YOLO('yolov8n.yaml').load('yolov8m-seg.pt')
# Out:
# Transferred 95/355 items from pretrained weights

# %%
results = model_v8m.train(data='./config.yaml',optimizer='RAdam', imgsz=640, epochs=10, lr0=0.01, freeze=10, project='runs/segment', name='v8m_10_RAdamlr1_aug', augment = True)

# %%
#10 epochs:
model_v8m = YOLO('yolov8m-seg.pt')
model_v8m.train(data='./config.yaml',optimizer='RAdam', imgsz=640, epochs=10, lr0=0.01, freeze=10, project='runs/segment', name='v8m_10_RAdamlr1_aug', augment = True)
# Out:
# Ultralytics 8.3.145  Python-3.9.13 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
#25 epochs:
model_v8m = YOLO('yolov8m-seg.pt')
model_v8m.train(data='./config.yaml',optimizer='RAdam', imgsz=640, epochs=25, lr0=0.01, freeze=10, project='runs/segment', name='v8m_25_RAdamlr1_aug', augment = True)
# Out:
# Ultralytics 8.3.145  Python-3.9.13 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %% [markdown]
# Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))

# %% [markdown]
# ##### v8m - 25

# %%
#25 epochs:
model_v8m = YOLO('yolov8m-seg.pt')
model_v8m.train(data='./config.yaml', optimizer='RAdam', imgsz=640, epochs=25, lr0=0.01, freeze=10, project='runs/segment', name='v8m_25_RAdam')
metrics = model_v8m.val()
print(metrics)
# Out:
# Ultralytics 8.3.145  Python-3.9.13 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
#25 epochs:
model_v8m = YOLO('yolov8m-seg.pt')
model_v8m.train(data='./config.yaml', imgsz=640, epochs=25, lr0=0.01, freeze=10, project='runs/segment', name='v8m_25')
metrics = model_v8m.val()
print(metrics)
# Out:
# Ultralytics 8.3.145  Python-3.9.13 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %% [markdown]
# ##### v8m - 50

# %%
#50 epochs:
model_v8m = YOLO('yolov8m-seg.pt')
model_v8m.train(data='./config.yaml', imgsz=640, epochs=50, lr0=0.01, freeze=10, project='runs/segment', name='v8m_50')
metrics = model_v8m.val()
print(metrics)

# %%
model_v8m = YOLO('yolov8m-seg.pt')
model_v8m.train(data='./config.yaml',optimizer='RAdam', imgsz=640, epochs=50, lr0=0.01, freeze=10, project='runs/segment', name='v8m_50_RAdamlr1_aug', augment = True)
# Out:
# Ultralytics 8.3.145  Python-3.9.13 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %% [markdown]
# * YOLOv8s:

# %%
model_v8s = YOLO('yolov8s-seg.pt')

# %%
model_v8s.info()
# Out:
# YOLOv8s-seg summary: 151 layers, 11,821,056 parameters, 0 gradients, 42.9 GFLOPs
# (151, 11821056, 0, 42.860595200000006)

# %% [markdown]
# ##### v8s - 10

# %%
model_v8s = YOLO('yolov8s-seg.pt')
model_v8s.info()
# Out:
# YOLOv8s-seg summary: 151 layers, 11,821,056 parameters, 0 gradients, 42.9 GFLOPs
# (151, 11821056, 0, 42.860595200000006)

# %%
model_v8s = YOLO('yolov8s-seg.pt')

model_v8s.train(data='./config.yaml',optimizer='RAdam', imgsz=640, epochs=10, lr0=0.01, freeze=10, project='runs/segment', name='v8s_10_RAdamlr1_aug', augment = True)
# Out:
# Ultralytics 8.3.145  Python-3.9.13 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %% [markdown]
# ##### v8s - 25

# %%
#25 epochs:
model_v8s = YOLO('yolov8s-seg.pt')
model_v8s.train(data='./config.yaml', imgsz=640, epochs=25, lr0=0.01, freeze=10, project='runs/segment', name='v8s_25')
metrics = model_v8s.val()
print(metrics)

# %%
model_v8s = YOLO('yolov8s-seg.pt')

model_v8s.train(data='./config.yaml',optimizer='RAdam', imgsz=640, epochs=25, lr0=0.01, freeze=10, project='runs/segment', name='v8s_25_RAdamlr1_aug', augment = True)
# Out:
# Ultralytics 8.3.145  Python-3.9.13 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %% [markdown]
# ##### v8s - 50

# %%
#10 epochs:
model_v8s = YOLO('yolov8s-seg.pt')

model_v8s.train(data='./config.yaml',optimizer='RAdam', imgsz=640, epochs=50, lr0=0.01, freeze=10, project='runs/segment', name='v8s_50_RAdamlr1_aug', augment = True)
# Out:
# Ultralytics 8.3.145  Python-3.9.13 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
#50 epochs:
model_v8s = YOLO('yolov8s-seg.pt')
model_v8s.train(data='./config.yaml', imgsz=640, epochs=50, lr0=0.01, freeze=10, project='runs/segment', name='v8s_50')
metrics = model_v8s.val()
print(metrics)

# %% [markdown]
# ---
# #### Yolov8l

# %%
model_v8l = YOLO('yolov8l-seg.pt')
model_v8l.info()
# Out:
# ...
# 100%|██████████| 88.1M/88.1M [00:03<00:00, 25.6MB/s]
# YOLOv8l-seg summary: 231 layers, 45,997,728 parameters, 0 gradients, 221.1 GFLOPs
# (231, 45997728, 0, 221.13428480000005)

# %%
model_v8l = YOLO('yolov8l-seg.pt')

model_v8l.train(data='./config.yaml',optimizer='RAdam', imgsz=640, epochs=10, lr0=0.01, freeze=10, project='runs/segment', name='v8l_10_RAdamlr1_aug', augment = True)
# Out:
# New https://pypi.org/project/ultralytics/8.3.146 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.145  Python-3.9.13 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
model_v8l = YOLO('yolov8l-seg.pt')

model_v8l.train(data='./config.yaml',optimizer='RAdam', imgsz=640, epochs=25, lr0=0.01, freeze=10, project='runs/segment', name='v8l_25_RAdamlr1_aug', augment = True)
# Out:
# Ultralytics 8.3.145  Python-3.9.13 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
model_v8l = YOLO('yolov8l-seg.pt')

model_v8l.train(data='./config.yaml',optimizer='RAdam', imgsz=640, epochs=50, lr0=0.01, freeze=10, project='runs/segment', name='v8l_50_RAdamlr1_aug', augment = True)
# Out:
# Ultralytics 8.3.145  Python-3.9.13 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %% [markdown]
# ---
# #### Yolov11

# %% [markdown]
# YOLO model (you can choose n, s, m, l, or x versions) https://docs.ultralytics.com/tasks/segment/

# %% [markdown]
# para o yolo 11 nao sei quanto de learning rate usar, ams comecemos com 0.01

# %% [markdown]
# * yolo11

# %%
model_y11n = YOLO("yolo11n-seg.pt")

# %%
#5 epochs:
model_y11n = YOLO("yolo11n-seg.pt")
model_y11n.train(data='./config.yaml', imgsz=640, epochs=5, lr0=0.01, freeze=10, project='runs/segment', name='y11n_5')
# Out:
# Ultralytics 8.3.145  Python-3.9.13 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
metrics = model_y11n.val()
print(metrics)
# Out:
# Ultralytics 8.3.145  Python-3.9.13 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# YOLO11n-seg summary (fused): 113 layers, 2,836,713 parameters, 0 gradients, 10.2 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 588.6222.4 MB/s, size: 78.6 KB)
# val: Scanning C:\Users\Carol\Mestrado\Semestre 2\DeepLearning\2025 project\deep_learning_car_damage\Car-Damage-Image-segmentation\Car-damage-image-seg\data\valid\labels.cache... 401 images, 0 backgrounds, 0 corrupt: 100%|██████████| 401/401 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95):   0%|          | 0/26 [00:00<?, ?it/s]
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# WARNING Limiting validation plots to first 50 items per image for speed...
# ...

# %%
#10 epochs
model_y11n = YOLO("yolo11n-seg.pt")
model_y11n.train(data='./config.yaml', imgsz=640, epochs=10, lr0=0.01, freeze=10, project='runs/segment', name='y11n_10')
metrics = model_y11n.val()
print(metrics)
# Out:
# Ultralytics 8.3.145  Python-3.9.13 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
#15 epochs
model_y11n = YOLO("yolo11n-seg.pt")
model_y11n.train(data='./config.yaml', imgsz=640, epochs=15, lr0=0.01, freeze=10, project='runs/segment', name='y11n_15')
metrics = model_y11n.val()
print(metrics)

# %%
#30 epochs:
model_y11n = YOLO("yolo11n-seg.pt")
model_y11n.train(data='./config.yaml', imgsz=640, epochs=30, lr0=0.01, freeze=10, project='runs/segment', name='y11n_30')
metrics = model_y11n.val()
print(metrics)

# %% [markdown]
# * yolo11l

# %%
model_y11l = YOLO("yolo11l-seg.pt")

# %%
#5 epochs:
model_y11l = YOLO("yolo11l-seg.pt")
model_y11l.train(data='./config.yaml', imgsz=640, epochs=5, lr0=0.01, freeze=10, project='runs/segment', name='y11l_5')
metrics = model_y11l.val()
print(metrics)

# %%
#15 epochs:
model_y11l = YOLO("yolo11l-seg.pt")
model_y11l.train(data='./config.yaml', imgsz=640, epochs=15, lr0=0.01, freeze=10, project='runs/segment', name='y11l_15')
metrics = model_y11l.val()
print(metrics)

# %%
#30 epochs:
model_y11l = YOLO("yolo11l-seg.pt")
model_y11l.train(data='./config.yaml', imgsz=640, epochs=30, lr0=0.01, freeze=10, project='runs/segment', name='y11l_30')
metrics = model_y11l.val()
print(metrics)

# %% [markdown]
# ---
# #### Prediction:

# %% [markdown]
# a prediction so vamos usar depois de escolhermos , ou entao podemos fazer para comparar modelos:

# %%
#aqui tens que ver qual o ficheiro em que fica guardado os saves do modelo
#also, esta o last mas tambem podemos testar com o 'best'
model = YOLO('./runs/segment/v8m_102/weights/last.pt')

results = model('./car_1.jpg', imgsz=640)

annotated = results[0].plot()
cv2.imwrite('car_1_overlay.png', annotated)
# Out:
# image 1/1 c:\Users\Carol\Mestrado\Semestre 2\DeepLearning\2025 project\deep_learning_car_damage\Car-Damage-Image-segmentation\Car-damage-image-seg\car_1.jpg: 320x640 1 lamp-crack, 1 moderate-deformation, 88.8ms
# Speed: 6.3ms preprocess, 88.8ms inference, 19.2ms postprocess per image at shape (1, 3, 320, 640)
# True

# %%
#neste, alterei o nivel de confiança para aparecer mais ou menos labels:
results = model.predict(source='./car_1.jpg', conf=0.25, show=True)

#source = data/test/images, name = v8m_10_infer

annotated = results[0].plot()

cv2.imwrite('car_1_overlay_conf.png', annotated)

# %%
model = YOLO('./runs/segment/v8l_50_RAdamlr1_aug/weights/last.pt')

results = model('./car_1.jpg', imgsz=640)

annotated = results[0].plot()
cv2.imwrite('car_1_overlay.png', annotated)
# Out:
# image 1/1 c:\Users\Carol\Mestrado\Semestre 2\DeepLearning\2025 project\deep_learning_car_damage\Car-Damage-Image-segmentation\Car-damage-image-seg\car_1.jpg: 320x640 1 car-part-crack, 1 detachment, 1 lamp-crack, 2 moderate-deformations, 72.1ms
# Speed: 4.0ms preprocess, 72.1ms inference, 23.0ms postprocess per image at shape (1, 3, 320, 640)
# True

# %%
model = YOLO('./runs/segment/v8l_50_RAdamlr1_aug/weights/last.pt')

results = model('./001979_jpg.rf.f8c39caa13981cd0f8c305a155df027a.jpg', imgsz=640, conf=0.2)

annotated = results[0].plot()
cv2.imwrite('car_test_overlay.png', annotated)
# Out:
# image 1/1 c:\Users\Carol\Mestrado\Semestre 2\DeepLearning\2025 project\deep_learning_car_damage\Car-Damage-Image-segmentation\Car-damage-image-seg\001979_jpg.rf.f8c39caa13981cd0f8c305a155df027a.jpg: 448x640 5 car-part-cracks, 1 paint-chips, 2 scratchess, 26.9ms
# Speed: 1.4ms preprocess, 26.9ms inference, 2.6ms postprocess per image at shape (1, 3, 448, 640)
# True

# %%
model = YOLO('./runs/segment/v8l_50_RAdamlr1_aug/weights/best.pt')

results = model('./000078_jpg.rf.ea0c7cc20b4b58c131733f083ab1fda2.jpg', imgsz=640, conf=0.2)

annotated = results[0].plot()
cv2.imwrite('car_test_overlay.png', annotated)
# Out:
# image 1/1 c:\Users\Carol\Mestrado\Semestre 2\DeepLearning\2025 project\deep_learning_car_damage\Car-Damage-Image-segmentation\Car-damage-image-seg\000078_jpg.rf.ea0c7cc20b4b58c131733f083ab1fda2.jpg: 640x448 1 lamp-crack, 1 moderate-deformation, 64.9ms
# Speed: 1.7ms preprocess, 64.9ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 448)
# True

# %% [markdown]
# ##### so para testar:

# %%
# !yolo task=segment \
mode=predict \
model=runs/segment/v8m_10/weights/best.pt \
source = data/test/images \
imgsz=640 \
name=v8m_10_infer
# Out:
# Ultralytics 8.3.145  Python-3.9.13 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# YOLOv8m-seg summary (fused): 105 layers, 27,228,753 parameters, 0 gradients, 110.0 GFLOPs
#
# image 1/204 c:\Users\Carol\Mestrado\Semestre 2\DeepLearning\2025 project\deep_learning_car_damage\Car-Damage-Image-segmentation\Car-damage-image-seg\data\test\images\000078_jpg.rf.ea0c7cc20b4b58c131733f083ab1fda2.jpg: 640x448 1 lamp-crack, 1 moderate-deformation, 169.8ms
# image 2/204 c:\Users\Carol\Mestrado\Semestre 2\DeepLearning\2025 project\deep_learning_car_damage\Car-Damage-Image-segmentation\Car-damage-image-seg\data\test\images\000106_jpg.rf.a5df3aa24c8ceff96f88e4319dd07233.jpg: 448x640 1 lamp-crack, 120.4ms
# image 3/204 c:\Users\Carol\Mestrado\Semestre 2\DeepLearning\2025 project\deep_learning_car_damage\Car-Damage-Image-segmentation\Car-damage-image-seg\data\test\images\000107_jpg.rf.d4e125b714d6934cc198dc1c1fe8b390.jpg: 448x640 3 scratchess, 15.9ms
# ...

# %%
import matplotlib.pyplot as plt
import glob 
import random
import os

# %%
# 1) Run inference and get the result object
model = YOLO('runs/segment/v8s_10/weights/best.pt')
results = model.predict('car_1.jpg', imgsz=640)

# 2) Grab the first result and render it inline
annotated = results[0].plot()  # draws masks, boxes and labels

# 3) Show it
plt.figure(figsize=(8,8))
plt.imshow(cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB))
plt.axis('off')
# Out:
# image 1/1 c:\Users\Carol\Mestrado\Semestre 2\DeepLearning\2025 project\deep_learning_car_damage\Car-Damage-Image-segmentation\Car-damage-image-seg\car_1.jpg: 320x640 1 car-part-crack, 1 detachment, 1 lamp-crack, 2 scratchess, 80.3ms
# Speed: 2.7ms preprocess, 80.3ms inference, 16.5ms postprocess per image at shape (1, 3, 320, 640)
# (np.float64(-0.5), np.float64(979.5), np.float64(444.5), np.float64(-0.5))

# %%
# 3) Show it
plt.figure(figsize=(8,8))
plt.imshow(cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB))
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(979.5), np.float64(444.5), np.float64(-0.5))

# %%
# Plot and visualize images in a 2x2 grid.
def visualize(result_dir, num_samples=4):
    """
    Function accepts a list of images and plots
    them in a 2x2 grid.
    """
    plt.figure(figsize=(20, 12))
    image_names = glob.glob(os.path.join(result_dir, '*.jpg'))
    random.shuffle(image_names)
    for i, image_name in enumerate(image_names):
        image = plt.imread(image_name)
        plt.subplot(2, 2, i+1)
        plt.imshow(image)
        plt.axis('off')
        if i == num_samples-1:
            break
    plt.tight_layout()
    plt.show()

# %%
visualize('runs/segment/v8m_10_infer/')
plt.show()

# %% [markdown]
# !yolo \
# task = segment \
# mode = predict \
# model = runs/segment/v8s_10/weights/best.pt \
# source = car_1.jpg \

# %%
model = YOLO('./runs/segment/v8s_10/weights/last.pt')

results = model('./car_1.jpg', imgsz=640)

annotated = results[0].plot()
cv2.imwrite('car_1_overlay2.png', annotated)

# %% [markdown]
# ##### v8s -10

# %%
model_last = YOLO('./runs/segment/v8s_10/weights/last.pt')
model_best = YOLO('./runs/segment/v8s_10/weights/best.pt')

# %%
results_last = model_last('./car_1.jpg', imgsz=640)
results_best = model_best('./car_1.jpg', imgsz=640)
annotated_l = results_last[0].plot()
annotated_b = results_best[0].plot()

cv2.imwrite('v8s10_last_overlay.png', annotated_l)
cv2.imwrite('v8s10_best_overlay.png', annotated_b)
# Out:
# image 1/1 c:\Users\Carol\Mestrado\Semestre 2\DeepLearning\2025 project\deep_learning_car_damage\Car-Damage-Image-segmentation\Car-damage-image-seg\car_1.jpg: 320x640 1 car-part-crack, 1 detachment, 1 lamp-crack, 2 scratchess, 212.7ms
# Speed: 3.0ms preprocess, 212.7ms inference, 31.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\Carol\Mestrado\Semestre 2\DeepLearning\2025 project\deep_learning_car_damage\Car-Damage-Image-segmentation\Car-damage-image-seg\car_1.jpg: 320x640 1 car-part-crack, 1 detachment, 1 lamp-crack, 2 scratchess, 9.2ms
# Speed: 1.3ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# True

# %% [markdown]
# ##### y11n - 5

# %%
model_last = YOLO('./runs/segment/y11n_5/weights/last.pt')
model_best = YOLO('./runs/segment/y11n_5/weights/best.pt')

# %%
results_last = model_last('./car_1.jpg', imgsz=640)
results_best = model_best('./car_1.jpg', imgsz=640)
annotated_l = results_last[0].plot()
annotated_b = results_best[0].plot()

cv2.imwrite('y11n5_last_overlay.png', annotated_l)
cv2.imwrite('y11n5_best_overlay.png', annotated_b)
# Out:
# image 1/1 c:\Users\Carol\Mestrado\Semestre 2\DeepLearning\2025 project\deep_learning_car_damage\Car-Damage-Image-segmentation\Car-damage-image-seg\car_1.jpg: 320x640 1 lamp-crack, 76.9ms
# Speed: 3.1ms preprocess, 76.9ms inference, 25.9ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 c:\Users\Carol\Mestrado\Semestre 2\DeepLearning\2025 project\deep_learning_car_damage\Car-Damage-Image-segmentation\Car-damage-image-seg\car_1.jpg: 320x640 1 lamp-crack, 13.0ms
# Speed: 5.6ms preprocess, 13.0ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
# True

# %%
model_last = YOLO('./runs/segment/y11n_5/weights/last.pt')
results_last = model_last('./car_1.jpg', imgsz=640)

annotated_l = results_last[0].plot()

cv2.imwrite('y11n5_last_overlay.png', annotated_l)

# %%
#neste, alterei o nivel de confiança para aparecer mais ou menos labels:
results = model_y11n.predict(source='./car_1.jpg', conf=0.2, show=True)
annotated = results[0].plot()

cv2.imwrite('y11n5_last_overlay_conf.png', annotated)
# Out:
# image 1/1 c:\Users\Carol\Mestrado\Semestre 2\DeepLearning\2025 project\deep_learning_car_damage\Car-Damage-Image-segmentation\Car-damage-image-seg\car_1.jpg: 320x640 1 lamp-crack, 1 scratches, 27.7ms
# Speed: 2.6ms preprocess, 27.7ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
# True

# %% [markdown]
# ##### y11n - 10

# %%
model_last = YOLO('./runs/segment/y11n_10/weights/last.pt')
results_last = model_last('./car_1.jpg', imgsz=640)

annotated_l = results_last[0].plot()

cv2.imwrite('y11n10_last_overlay.png', annotated_l)
# Out:
# image 1/1 c:\Users\Carol\Mestrado\Semestre 2\DeepLearning\2025 project\deep_learning_car_damage\Car-Damage-Image-segmentation\Car-damage-image-seg\car_1.jpg: 320x640 1 scratches, 19.8ms
# Speed: 6.1ms preprocess, 19.8ms inference, 10.7ms postprocess per image at shape (1, 3, 320, 640)
# True
